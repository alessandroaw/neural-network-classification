# %%
from PIL import Image
import numpy as np
import random

# %%
#try load training set
import numpy as np
train_filename="el4233-2018-2019-02-ann-klasifikasi-train.csv"
test_filename="el4233-2018-2019-02-ann-klasifikasi-test.csv"
training=np.genfromtxt(train_filename,delimiter=',')

# %%
training_x=training[:,1]

# %%
training_y=training[:,2]

# %%
training_z=training[:,3]

# %%
#plot saja

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10)) 
plt.scatter(training_x, training_y, c=training_z)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
from sklearn.neural_network import MLPClassifier

# %%
testing=np.genfromtxt(test_filename,delimiter=',')

# %%
testing.shape
# Out:
# (10000, 3)

# %%
testing_x=testing[:,1]
testing_y=testing[:,2]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10)) 
plt.scatter(testing_x, testing_y)
plt.xlabel("x")
plt.ylabel("y")
